# %%
import pandas as pd
df=pd.read_csv("/Users/amrendraupadhyay/Downloads/weather_data_bycities.csv")
df
# Out:
#          day      city  temperature  windspeed   event
# 0   01/01/17  new york           92         13   Rainy
# 1   01/02/17  new york           36          7   Sunny
# 2   01/03/17  new york           28         12    Snow
# 3   01/04/17  new york           33          7   Sunny
# 4   01/01/17    mumbai           90          5   Sunny
# 5   01/02/17    mumbai           85         12     Fog
# 6   01/03/17    mumbai           87         15     Fog
# 7   01/04/17    mumbai           92          5    Rain
# 8   01/01/17     paris           45         20   Sunny
# 9   01/02/17     paris           50         13  Cloudy
# 10  01/03/17     paris           54          8  Cloudy
# 11  01/04/17     paris           42         10  Cloudy

# %%
# Creating Group_by dataframe.
groupby_df=df.groupby("city")
groupby_df

# %% [markdown]
# # DataFrameGroupBy object looks something like below,
#
# ![image.png](attachment:image.png)

# %%
#groupby dataframe stores the data in key,value pairs.
# Accessing the values of groupby_df
for keys,values in groupby_df:
    print(keys)
    print(values)
# Out:
# mumbai
#         day    city  temperature  windspeed  event
# 4  01/01/17  mumbai           90          5  Sunny
# 5  01/02/17  mumbai           85         12    Fog
# 6  01/03/17  mumbai           87         15    Fog
# 7  01/04/17  mumbai           92          5   Rain
# new york
#         day      city  temperature  windspeed  event
# 0  01/01/17  new york           92         13  Rainy
# 1  01/02/17  new york           36          7  Sunny
# 2  01/03/17  new york           28         12   Snow
# 3  01/04/17  new york           33          7  Sunny
# paris
#          day   city  temperature  windspeed   event
# 8   01/01/17  paris           45         20   Sunny
# 9   01/02/17  paris           50         13  Cloudy
# 10  01/03/17  paris           54          8  Cloudy
# 11  01/04/17  paris           42         10  Cloudy

# %%
# Accessing data using get_group method
groupby_df.get_group("mumbai")
# Out:
#         day    city  temperature  windspeed  event
# 4  01/01/17  mumbai           90          5  Sunny
# 5  01/02/17  mumbai           85         12    Fog
# 6  01/03/17  mumbai           87         15    Fog
# 7  01/04/17  mumbai           92          5   Rain

# %% [markdown]
# # For this dataset, get following answers,
# 1. What was the maximum temperature in each of these 3 cities?
# 2. What was the average windspeed in each of these 3 cities?

# %%
groupby_df.max()
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    01/04/17           92         15  Sunny
# new york  01/04/17           92         13  Sunny
# paris     01/04/17           54         20  Sunny

# %%
groupby_df.mean()
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        47.25       9.75
# paris           47.75      12.75

# %%
groupby_df.mean()
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        47.25       9.75
# paris           47.75      12.75

# %% [markdown]
# # This method of splitting your dataset in smaller groups and then applying an operation (such as min or max) to get aggregate result is called Split-Apply-Combine. It is illustrated in a diagram below
#
# ![image.png](attachment:image.png)

# %%
groupby_df.describe()
# Out:
#          temperature                                                   \
#                count   mean        std   min    25%   50%   75%   max
# city
# mumbai           4.0  88.50   3.109126  85.0  86.50  88.5  90.5  92.0
# new york         4.0  47.25  30.015274  28.0  31.75  34.5  50.0  92.0
# paris            4.0  47.75   5.315073  42.0  44.25  47.5  51.0  54.0
#
#          windspeed
#              count   mean       std  min  25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.0   8.5  12.75  15.0
# new york       4.0   9.75  3.201562  7.0  7.0   9.5  12.25  13.0
# paris          4.0  12.75  5.251984  8.0  9.5  11.5  14.75  20.0

# %%
groupby_df.size()
# Out:
# city
# mumbai      4
# new york    4
# paris       4
# dtype: int64

# %%
groupby_df.count()
# Out:
#           day  temperature  windspeed  event
# city
# mumbai      4            4          4      4
# new york    4            4          4      4
# paris       4            4          4      4

# %%
# Plotting the data using matplotlib
# %matplotlib inline
groupby_df.plot()
# Out:
# city
# mumbai      AxesSubplot(0.125,0.125;0.775x0.755)
# new york    AxesSubplot(0.125,0.125;0.775x0.755)
# paris       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
