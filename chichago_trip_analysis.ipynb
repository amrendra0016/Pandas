# %%
import pandas as pd
df =pd.read_csv("/Users/amrendraupadhyay/Downloads/Amrendra_practice_file/chicago.csv",parse_dates=["Start Time"])
df
# Out:
#         Unnamed: 0          Start Time        End Time  Trip Duration  \
# 0          1423854 2017-06-23 15:09:00  23/06/17 15:14            321
# 1           955915 2017-05-25 18:19:00  25/05/17 18:45           1610
# 2             9031 2017-04-01 08:27:00   04/01/17 8:34            416
# 3           304487 2017-06-03 13:49:00  06/03/17 13:55            350
# 4            45207 2017-01-17 14:53:00  17/01/17 15:02            534
# ...            ...                 ...             ...            ...
# 299995       64825 2017-01-21 13:18:00  21/01/17 13:27            590
# 299996      695993 2017-04-28 19:32:00  28/04/17 19:51           1139
# 299997      159685 2017-12-02 09:59:00  12/02/17 10:21           1368
# 299998      564681 2017-04-16 17:07:00  16/04/17 17:19            705
# 299999     1021247 2017-05-30 12:38:00  30/05/17 12:55           1028
#
#                         Start Station                   End Station  \
# ...

# %%
df.head(2)
# Out:
#    Unnamed: 0          Start Time        End Time  Trip Duration  \
# 0     1423854 2017-06-23 15:09:00  23/06/17 15:14            321
# 1      955915 2017-05-25 18:19:00  25/05/17 18:45           1610
#
#           Start Station                   End Station   User Type  Gender  \
# 0  Wood St & Hubbard St       Damen Ave & Chicago Ave  Subscriber    Male
# 1   Theater on the Lake  Sheffield Ave & Waveland Ave  Subscriber  Female
#
#    Birth Year
# 0      1992.0
# 1      1992.0

# %%
type(df['Start Time'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
def get_dom(dt):
    return dt.day

df['sdom'] = df['Start Time'].map(get_dom)

# %%
def get_dom(dt):
    return dt.month

df['s_month'] = df['Start Time'].map(get_dom)

# %%
df
# Out:
#         Unnamed: 0          Start Time        End Time  Trip Duration  \
# 0          1423854 2017-06-23 15:09:00  23/06/17 15:14            321
# 1           955915 2017-05-25 18:19:00  25/05/17 18:45           1610
# 2             9031 2017-04-01 08:27:00   04/01/17 8:34            416
# 3           304487 2017-06-03 13:49:00  06/03/17 13:55            350
# 4            45207 2017-01-17 14:53:00  17/01/17 15:02            534
# ...            ...                 ...             ...            ...
# 299995       64825 2017-01-21 13:18:00  21/01/17 13:27            590
# 299996      695993 2017-04-28 19:32:00  28/04/17 19:51           1139
# 299997      159685 2017-12-02 09:59:00  12/02/17 10:21           1368
# 299998      564681 2017-04-16 17:07:00  16/04/17 17:19            705
# 299999     1021247 2017-05-30 12:38:00  30/05/17 12:55           1028
#
#                         Start Station                   End Station  \
# ...

# %%
df['month'] = df['Start Time'].dt.month_name()
df
# Out:
#         Unnamed: 0          Start Time        End Time  Trip Duration  \
# 0          1423854 2017-06-23 15:09:00  23/06/17 15:14            321
# 1           955915 2017-05-25 18:19:00  25/05/17 18:45           1610
# 2             9031 2017-04-01 08:27:00   04/01/17 8:34            416
# 3           304487 2017-06-03 13:49:00  06/03/17 13:55            350
# 4            45207 2017-01-17 14:53:00  17/01/17 15:02            534
# ...            ...                 ...             ...            ...
# 299995       64825 2017-01-21 13:18:00  21/01/17 13:27            590
# 299996      695993 2017-04-28 19:32:00  28/04/17 19:51           1139
# 299997      159685 2017-12-02 09:59:00  12/02/17 10:21           1368
# 299998      564681 2017-04-16 17:07:00  16/04/17 17:19            705
# 299999     1021247 2017-05-30 12:38:00  30/05/17 12:55           1028
#
#                         Start Station                   End Station  \
# ...

# %% [markdown]
# # display the most common month

# %%
groupby_df=df.groupby("month")
groupby_df

# %%
#l=[]
d={}
for keys,values in groupby_df:
    #l.append(values.count().max())
    d[keys]=values.count().max()
    print(keys,values.count().max())
d
# Out:
# April 42152
# August 10069
# December 9337
# February 30543
# January 23467
# July 8928
# June 66286
# March 27276
# May 53093
# November 9260
# October 9073
# September 10516
# {'April': 42152,
#  'August': 10069,
#  'December': 9337,
#  'February': 30543,
#  'January': 23467,
#  'July': 8928,
#  'June': 66286,
#  'March': 27276,
#  'May': 53093,
#  'November': 9260,
#  'October': 9073,
#  'September': 10516}

# %%
# finding key having maximum value 
max(d,key=d.get)
# Out:
# 'June'

# %% [markdown]
# # display the most common day_of_week

# %%
df['day_of_week'] = df['Start Time'].dt.day_name()
df
# Out:
#         Unnamed: 0          Start Time        End Time  Trip Duration  \
# 0          1423854 2017-06-23 15:09:00  23/06/17 15:14            321
# 1           955915 2017-05-25 18:19:00  25/05/17 18:45           1610
# 2             9031 2017-04-01 08:27:00   04/01/17 8:34            416
# 3           304487 2017-06-03 13:49:00  06/03/17 13:55            350
# 4            45207 2017-01-17 14:53:00  17/01/17 15:02            534
# ...            ...                 ...             ...            ...
# 299995       64825 2017-01-21 13:18:00  21/01/17 13:27            590
# 299996      695993 2017-04-28 19:32:00  28/04/17 19:51           1139
# 299997      159685 2017-12-02 09:59:00  12/02/17 10:21           1368
# 299998      564681 2017-04-16 17:07:00  16/04/17 17:19            705
# 299999     1021247 2017-05-30 12:38:00  30/05/17 12:55           1028
#
#                         Start Station                   End Station  \
# ...

# %%
groupby_df1=df.groupby("day_of_week")
groupby_df1

# %%
#l=[]
d={}
for keys,values in groupby_df1:
    #l.append(values.count().max())
    d[keys]=values.count().max()
    print(keys,values.count().max())
d
# Out:
# Friday 42756
# Monday 50991
# Saturday 37996
# Sunday 37966
# Thursday 40341
# Tuesday 45590
# Wednesday 44360
# {'Friday': 42756,
#  'Monday': 50991,
#  'Saturday': 37996,
#  'Sunday': 37966,
#  'Thursday': 40341,
#  'Tuesday': 45590,
#  'Wednesday': 44360}

# %%
# finding key having maximum value 
max(d,key=d.get)
# Out:
# 'Monday'

# %%
df['common_hour_week'] = df['Start Time'].dt.hour
df
# Out:
#         Unnamed: 0          Start Time        End Time  Trip Duration  \
# 0          1423854 2017-06-23 15:09:00  23/06/17 15:14            321
# 1           955915 2017-05-25 18:19:00  25/05/17 18:45           1610
# 2             9031 2017-04-01 08:27:00   04/01/17 8:34            416
# 3           304487 2017-06-03 13:49:00  06/03/17 13:55            350
# 4            45207 2017-01-17 14:53:00  17/01/17 15:02            534
# ...            ...                 ...             ...            ...
# 299995       64825 2017-01-21 13:18:00  21/01/17 13:27            590
# 299996      695993 2017-04-28 19:32:00  28/04/17 19:51           1139
# 299997      159685 2017-12-02 09:59:00  12/02/17 10:21           1368
# 299998      564681 2017-04-16 17:07:00  16/04/17 17:19            705
# 299999     1021247 2017-05-30 12:38:00  30/05/17 12:55           1028
#
#                         Start Station                   End Station  \
# ...

# %%
groupby_df2=df.groupby("common_hour_week")
groupby_df2

# %%
d={}
for keys,values in groupby_df2:
    #l.append(values.count().max())
    d[keys]=values.count().max()
    print(keys,values.count().max())
d
# Out:
# 0 1686
# 1 982
# 2 609
# 3 372
# 4 467
# 5 2437
# 6 8246
# 7 18380
# 8 24134
# 9 13691
# 10 11952
# 11 15040
# 12 17467
# 13 17559
# 14 17596
# 15 20108
# 16 28742
# 17 35992
# 18 23512
# 19 15715
# 20 10301
# 21 7103
# 22 4895
# 23 3014
# {0: 1686,
#  1: 982,
#  2: 609,
#  3: 372,
#  4: 467,
#  5: 2437,
#  6: 8246,
#  7: 18380,
#  8: 24134,
#  9: 13691,
#  10: 11952,
#  11: 15040,
#  12: 17467,
#  13: 17559,
#  14: 17596,
#  15: 20108,
#  16: 28742,
#  17: 35992,
#  18: 23512,
#  19: 15715,
#  20: 10301,
#  21: 7103,
#  22: 4895,
#  23: 3014}

# %% [markdown]
# # display the most common start hour

# %%
# finding key having maximum value 
max(d,key=d.get)
# Out:
# 17

# %% [markdown]
# # Most Commonly used Start Station

# %%
groupby_df3=df.groupby("Start Station")

# %%
d={}
for keys,values in groupby_df3:
    #l.append(values.count().max())
    d[keys]=values.count().max()
    print(keys,values.count().max())
d
# Out:
# 2112 W Peterson Ave 35
# 63rd St Beach 93
# 900 W Harrison St 467
# Aberdeen St & Jackson Blvd 722
# Aberdeen St & Monroe St 850
# Ada St & Washington Blvd 697
# Adler Planetarium 1737
# Albany (Kedzie) Ave & Montrose Ave 91
# Albany Ave & 26th St 11
# Albany Ave & Bloomingdale Ave 405
# Artesian Ave & Hubbard St 480
# Ashland Ave & 13th St 157
# Ashland Ave & 21st St 139
# Ashland Ave & 50th St 6
# Ashland Ave & 63rd St 3
# Ashland Ave & 69th St 1
# Ashland Ave & Archer Ave 44
# Ashland Ave & Augusta Blvd 495
# Ashland Ave & Belle Plaine Ave 274
# Ashland Ave & Blackhawk St 459
# Ashland Ave & Chicago Ave 602
# Ashland Ave & Division St 1222
# Ashland Ave & Grace St 391
# Ashland Ave & Grand Ave 370
# Ashland Ave & Harrison St 383
# Ashland Ave & Lake St 391
# Ashland Ave & McDowell Ave 26
# Ashland Ave & Pershing Rd 18
# Ashland Ave & Wellington Ave 241
# Ashland Ave & Wrightwood Ave 376
# Austin Blvd & Chicago Ave 14
# Austin Blvd & Lake St 29
# Avers Ave & Belmont Ave 80
# ...

# %%
max(d,key=d.get)
# Out:
# 'Streeter Dr & Grand Ave'

# %% [markdown]
# # display most commonly used end station

# %%
groupby_df4=df.groupby("End Station")

# %%
d={}
for keys,values in groupby_df4:
    #l.append(values.count().max())
    d[keys]=values.count().max()
    print(keys,values.count().max())
d
# Out:
# 2112 W Peterson Ave 44
# 63rd St Beach 92
# 900 W Harrison St 388
# Aberdeen St & Jackson Blvd 774
# Aberdeen St & Monroe St 897
# Ada St & Washington Blvd 693
# Adler Planetarium 1664
# Albany (Kedzie) Ave & Montrose Ave 103
# Albany Ave & 26th St 13
# Albany Ave & Bloomingdale Ave 352
# Artesian Ave & Hubbard St 338
# Ashland Ave & 13th St 171
# Ashland Ave & 21st St 126
# Ashland Ave & 50th St 4
# Ashland Ave & 63rd St 3
# Ashland Ave & 69th St 1
# Ashland Ave & Archer Ave 25
# Ashland Ave & Augusta Blvd 417
# Ashland Ave & Belle Plaine Ave 264
# Ashland Ave & Blackhawk St 467
# Ashland Ave & Chicago Ave 565
# Ashland Ave & Division St 1246
# Ashland Ave & Grace St 342
# Ashland Ave & Grand Ave 376
# Ashland Ave & Harrison St 338
# Ashland Ave & Lake St 357
# Ashland Ave & McDowell Ave 17
# Ashland Ave & Pershing Rd 16
# Ashland Ave & Wellington Ave 315
# Ashland Ave & Wrightwood Ave 333
# Austin Blvd & Chicago Ave 19
# Austin Blvd & Lake St 13
# Avers Ave & Belmont Ave 102
# ...

# %%
max(d,key=d.get)
# Out:
# 'Streeter Dr & Grand Ave'

# %%
d["Streeter Dr & Grand Ave"]
# Out:
# 7512

# %% [markdown]
# # display most frequent combination of start station and end station trip

# %%
groupby_df5=df.groupby(["Start Station","End Station"])
groupby_df5

# %%
d={}
for keys,values in groupby_df5:
    #l.append(values.count().max())
    d[keys]=values.count().max()
    #print(keys,values.count().max())
d
# Out:
# {('2112 W Peterson Ave', '2112 W Peterson Ave'): 1,
#  ('2112 W Peterson Ave', 'Broadway & Granville Ave'): 1,
#  ('2112 W Peterson Ave', 'Broadway & Thorndale Ave'): 3,
#  ('2112 W Peterson Ave', 'Clark St & Berwyn Ave'): 5,
#  ('2112 W Peterson Ave', 'Clark St & Bryn Mawr Ave'): 1,
#  ('2112 W Peterson Ave', 'Clark St & Jarvis Ave'): 1,
#  ('2112 W Peterson Ave', 'Clark St & Winnemac Ave'): 2,
#  ('2112 W Peterson Ave', 'Lincoln Ave & Belle Plaine Ave'): 2,
#  ('2112 W Peterson Ave', 'Maplewood Ave & Peterson Ave'): 1,
#  ('2112 W Peterson Ave', 'Oakley Ave & Irving Park Rd'): 1,
#  ('2112 W Peterson Ave', 'Ravenswood Ave & Balmoral Ave'): 2,
#  ('2112 W Peterson Ave', 'Ravenswood Ave & Lawrence Ave'): 1,
#  ('2112 W Peterson Ave', 'Sheridan Rd & Greenleaf Ave'): 1,
#  ('2112 W Peterson Ave', 'Warren Park East'): 8,
#  ('2112 W Peterson Ave', 'Washtenaw Ave & Lawrence Ave'): 4,
#  ('2112 W Peterson Ave', 'Western Ave & Lunt Ave'): 1,
#  ('63rd St Beach', '63rd St Beach'): 30,
# ...

# %%
max(d,key=d.get)
# Out:
# ('Lake Shore Dr & Monroe St', 'Streeter Dr & Grand Ave')

# %% [markdown]
# # display total travel time

# %%
df.head()
# Out:
#    Unnamed: 0          Start Time        End Time  Trip Duration  \
# 0     1423854 2017-06-23 15:09:00  23/06/17 15:14            321
# 1      955915 2017-05-25 18:19:00  25/05/17 18:45           1610
# 2        9031 2017-04-01 08:27:00   04/01/17 8:34            416
# 3      304487 2017-06-03 13:49:00  06/03/17 13:55            350
# 4       45207 2017-01-17 14:53:00  17/01/17 15:02            534
#
#                    Start Station                   End Station   User Type  \
# 0           Wood St & Hubbard St       Damen Ave & Chicago Ave  Subscriber
# 1            Theater on the Lake  Sheffield Ave & Waveland Ave  Subscriber
# 2             May St & Taylor St           Wood St & Taylor St  Subscriber
# 3  Christiana Ave & Lawrence Ave  St. Louis Ave & Balmoral Ave  Subscriber
# 4         Clark St & Randolph St  Desplaines St & Jackson Blvd  Subscriber
#
#    Gender  Birth Year day_of_week    month  common_hour_week
# 0    Male      1992.0      Friday     June                15
# ...

# %%
df['Trip Duration'].sum()
# Out:
# 280871787

# %% [markdown]
# # display mean travel time

# %%
df['Trip Duration'].mean()
# Out:
# 936.23929

# %% [markdown]
# # Display counts of user types

# %%
groupby_df6=df.groupby('User Type')
groupby_df6

# %%
for key,values in groupby_df6:
    print(key,values.count().max())
# Out:
# Customer 61110
# Dependent 1
# Subscriber 238889

# %% [markdown]
# # Display counts of gender

# %%
groupby_df7=df.groupby('Gender')
groupby_df7

# %%
for key,values in groupby_df7:
    print(key,values.count().max())
# Out:
# Female 57758
# Male 181190

# %% [markdown]
# # Display earliest, most recent, and most common year of birth

# %%
# Earliest year of birth
df['Birth Year'].min()
# Out:
# 1899.0

# %%
# # Most Recent year of birth
df['Birth Year'].max()
# Out:
# 2016.0

# %%
groupby_df8=df.groupby('Birth Year')
groupby_df8

# %%
d={}
for key,value in groupby_df8:
    d[key]=value.count().max()
    print(key,value.count().max())
d
# Out:
# 1899.0 14
# 1900.0 17
# 1901.0 9
# 1906.0 7
# 1909.0 2
# 1916.0 5
# 1918.0 46
# 1921.0 32
# 1930.0 3
# 1931.0 1
# 1934.0 30
# 1938.0 2
# 1939.0 39
# 1940.0 30
# 1941.0 23
# 1942.0 44
# 1943.0 6
# 1944.0 93
# 1945.0 148
# 1946.0 260
# 1947.0 64
# 1948.0 163
# 1949.0 570
# 1950.0 422
# 1951.0 648
# 1952.0 1054
# 1953.0 830
# 1954.0 1028
# 1955.0 1219
# 1956.0 1479
# 1957.0 1497
# 1958.0 1637
# 1959.0 1857
# 1960.0 2626
# 1961.0 2206
# 1962.0 2803
# 1963.0 2643
# 1964.0 2966
# 1965.0 2728
# 1966.0 3015
# 1967.0 2544
# 1968.0 3319
# 1969.0 3619
# 1970.0 3639
# 1971.0 2994
# 1972.0 3194
# 1973.0 3104
# 1974.0 3802
# 1975.0 3930
# 1976.0 4149
# 1977.0 5021
# 1978.0 4851
# 1979.0 5301
# 1980.0 6603
# 1981.0 7535
# 1982.0 8619
# 1983.0 8739
# 1984.0 10562
# 1985.0 10375
# 1986.0 11598
# 1987.0 11939
# 1988.0 12490
# 1989.0 14666
# 1990.0 12378
# 1991.0 12397
# 1992.0 11033
# 1993.0 8601
# 1994.0 4799
# 1995.0 1655
# 1996.0 1177
# 1997.0 1333
# 1998.0 506
# 1999.0 131
# 2000.0 84
# 2001.0 17
# ...

# %%
# most common birth year
max(d,key=d.get)
# Out:
# 1989.0
